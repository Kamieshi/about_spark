# %%
from pyspark.sql import SparkSession

# %%
session = (
    SparkSession
    .builder
    .master("local[2]")
    .appName("Driver")
    .getOrCreate()
)
session.conf.set("spark.sql.repl.eagerEval.enabled", True)
# Out:
# 22/09/07 09:58:47 WARN Utils: Your hostname, esw287 resolves to a loopback address: 127.0.1.1; using 192.168.1.81 instead (on interface enp2s0)
# 22/09/07 09:58:47 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 22/09/07 09:59:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
rdd_set = session.sparkContext.textFile("./input_data.txt",5)

# %%
rdd_set.count()
# Out:
# 109

# %%
phase_one = rdd_set.flatMap(lambda x: x.split(" "))
phase_one.collect()
# Out:
# ['Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet,',
#  'consectetur',
#  'adipiscing',
#  'elit.',
#  'Nunc',
#  'vitae',
#  'tempor',
#  'tortor.',
#  'Suspendisse',
#  'nec',
#  'ultrices',
#  'ex.',
#  'Etiam',
#  'non',
#  'egestas',
#  'mi.',
#  'Nulla',
#  'ipsum',
#  'massa,',
#  'auctor',
#  'et',
#  'accumsan',
#  'id,',
#  'fringilla',
#  'in',
#  'tortor.',
#  'Nulla',
#  'hendrerit',
#  'lectus',
#  'nec',
#  'enim',
#  'fermentum',
#  'consequat.',
#  'Maecenas',
#  'ac',
#  'metus',
#  'eget',
#  'nulla',
#  'viverra',
#  'elementum.',
#  'Suspendisse',
#  'euismod',
#  'eget',
#  'risus',
#  'id',
#  'varius.',
#  'Sed',
#  'scelerisque,',
#  'justo',
#  'et',
#  'luctus',
#  'cursus,',
#  'eros',
#  'tortor',
#  'commodo',
#  'nulla,',
#  'ac',
#  'volutpat',
#  'mi',
#  'ante',
#  'et',
#  'justo.',
#  '',
#  'Duis',
#  'dui',
#  'tellus,',
#  'blandit',
#  'accumsan',
#  'egestas',
#  'at,',
#  'bibendum',
#  'porttitor',
#  'nulla.',
#  'Ut',
#  'vestibulum',
# ...

# %%
phase_two = phase_one.map(lambda x:(x,1))
phase_two.collect()
# Out:
# [('Lorem', 1),
#  ('ipsum', 1),
#  ('dolor', 1),
#  ('sit', 1),
#  ('amet,', 1),
#  ('consectetur', 1),
#  ('adipiscing', 1),
#  ('elit.', 1),
#  ('Nunc', 1),
#  ('vitae', 1),
#  ('tempor', 1),
#  ('tortor.', 1),
#  ('Suspendisse', 1),
#  ('nec', 1),
#  ('ultrices', 1),
#  ('ex.', 1),
#  ('Etiam', 1),
#  ('non', 1),
#  ('egestas', 1),
#  ('mi.', 1),
#  ('Nulla', 1),
#  ('ipsum', 1),
#  ('massa,', 1),
#  ('auctor', 1),
#  ('et', 1),
#  ('accumsan', 1),
#  ('id,', 1),
#  ('fringilla', 1),
#  ('in', 1),
#  ('tortor.', 1),
#  ('Nulla', 1),
#  ('hendrerit', 1),
#  ('lectus', 1),
#  ('nec', 1),
#  ('enim', 1),
#  ('fermentum', 1),
#  ('consequat.', 1),
#  ('Maecenas', 1),
#  ('ac', 1),
#  ('metus', 1),
#  ('eget', 1),
#  ('nulla', 1),
#  ('viverra', 1),
#  ('elementum.', 1),
#  ('Suspendisse', 1),
#  ('euismod', 1),
#  ('eget', 1),
#  ('risus', 1),
#  ('id', 1),
#  ('varius.', 1),
#  ('Sed', 1),
#  ('scelerisque,', 1),
#  ('justo', 1),
#  ('et', 1),
#  ('luctus', 1),
#  ('cursus,', 1),
# ...

# %%
phase_three =  phase_two.groupByKey()
phase_three.collect()
# Out:
# [('elit.', <pyspark.resultiterable.ResultIterable at 0x7fcd016c3be0>),
#  ('Nunc', <pyspark.resultiterable.ResultIterable at 0x7fccfee0a9d0>),
#  ('non', <pyspark.resultiterable.ResultIterable at 0x7fccfee0ad90>),
#  ('lectus', <pyspark.resultiterable.ResultIterable at 0x7fccfee0aac0>),
#  ('fermentum', <pyspark.resultiterable.ResultIterable at 0x7fccfee0adc0>),
#  ('consequat.', <pyspark.resultiterable.ResultIterable at 0x7fccfee0ae20>),
#  ('Maecenas', <pyspark.resultiterable.ResultIterable at 0x7fccfee0a2e0>),
#  ('risus', <pyspark.resultiterable.ResultIterable at 0x7fccfee0aee0>),
#  ('id', <pyspark.resultiterable.ResultIterable at 0x7fccfee0af40>),
#  ('nulla,', <pyspark.resultiterable.ResultIterable at 0x7fccfee0ad60>),
#  ('mi', <pyspark.resultiterable.ResultIterable at 0x7fccfee0af10>),
#  ('', <pyspark.resultiterable.ResultIterable at 0x7fccfee0a730>),
#  ('at,', <pyspark.resultiterable.ResultIterable at 0x7fccfecfc070>),
# ...

# %%
phase_fore = phase_three.map(lambda x:(x[0],len(x[1])))
phase_fore.collect()
# Out:
# [('elit.', 15),
#  ('Nunc', 17),
#  ('non', 48),
#  ('lectus', 21),
#  ('fermentum', 17),
#  ('consequat.', 5),
#  ('Maecenas', 18),
#  ('risus', 22),
#  ('id', 66),
#  ('nulla,', 7),
#  ('mi', 22),
#  ('', 54),
#  ('at,', 5),
#  ('nulla.', 9),
#  ('ullamcorper', 24),
#  ('rutrum', 21),
#  ('malesuada,', 3),
#  ('mauris', 18),
#  ('aliquet', 11),
#  ('vel', 58),
#  ('at', 39),
#  ('Orci', 2),
#  ('natoque', 2),
#  ('magnis', 2),
#  ('dis', 2),
#  ('nascetur', 2),
#  ('mus.', 2),
#  ('Nam', 20),
#  ('mollis', 21),
#  ('nisl', 19),
#  ('convallis', 24),
#  ('ultrices,', 1),
#  ('feugiat', 22),
#  ('mattis', 12),
#  ('odio', 13),
#  ('fermentum,', 4),
#  ('venenatis.', 5),
#  ('eros,', 3),
#  ('condimentum', 17),
#  ('elementum', 18),
#  ('Aenean', 20),
#  ('neque', 23),
#  ('metus,', 4),
#  ('laoreet', 12),
#  ('elit', 25),
#  ('Nullam', 21),
#  ('urna', 15),
#  ('fringilla,', 5),
#  ('ex', 16),
#  ('eleifend', 20),
#  ('non.', 4),
#  ('urna.', 8),
#  ('ultricies', 14),
# ...

# %%
phase_five = phase_fore.sortBy(lambda x:x[1])
phase_five.collect()
# Out:
# [('ultrices,', 1),
#  ('condimentum.', 1),
#  ('venenatis,', 1),
#  ('vitae.', 1),
#  ('tempus,', 1),
#  ('viverra.', 1),
#  ('lacinia,', 1),
#  ('viverra,', 1),
#  ('turpis,', 1),
#  ('gravida,', 1),
#  ('blandit,', 1),
#  ('mollis,', 1),
#  ('sagittis,', 1),
#  ('orci,', 1),
#  ('tempus.', 1),
#  ('eleifend,', 1),
#  ('dictum.', 1),
#  ('euismod,', 1),
#  ('porttitor,', 1),
#  ('placerat,', 1),
#  ('vehicula,', 1),
#  ('auctor,', 1),
#  ('vulputate,', 1),
#  ('enim,', 1),
#  ('ullamcorper,', 1),
#  ('aliquet,', 1),
#  ('egestas,', 1),
#  ('iaculis,', 1),
#  ('efficitur.', 1),
#  ('aliquam,', 1),
#  ('luctus,', 1),
#  ('finibus,', 1),
#  ('dictum,', 1),
#  ('Orci', 2),
#  ('natoque', 2),
#  ('magnis', 2),
#  ('dis', 2),
#  ('nascetur', 2),
#  ('mus.', 2),
#  ('congue,', 2),
#  ('aliquam.', 2),
#  ('lobortis.', 2),
#  ('commodo.', 2),
#  ('posuere,', 2),
#  ('porttitor.', 2),
#  ('feugiat,', 2),
#  ('rhoncus,', 2),
#  ('maximus,', 2),
#  ('mattis,', 2),
#  ('suscipit.', 2),
# ...

# %%
easy_solution = rdd_set.flatMap(lambda x: x.split(" ")).map(lambda x: (x, 1)).reduceByKey(lambda x, y: x + y)
easy_solution.sortBy(lambda x:x[1]).collect()
# Out:
# [('vulputate,', 1),
#  ('enim,', 1),
#  ('condimentum.', 1),
#  ('venenatis,', 1),
#  ('placerat,', 1),
#  ('egestas,', 1),
#  ('tempus,', 1),
#  ('luctus,', 1),
#  ('orci,', 1),
#  ('eleifend,', 1),
#  ('viverra,', 1),
#  ('dictum.', 1),
#  ('euismod,', 1),
#  ('turpis,', 1),
#  ('auctor,', 1),
#  ('ultrices,', 1),
#  ('gravida,', 1),
#  ('ullamcorper,', 1),
#  ('vitae.', 1),
#  ('efficitur.', 1),
#  ('aliquet,', 1),
#  ('blandit,', 1),
#  ('mollis,', 1),
#  ('aliquam,', 1),
#  ('sagittis,', 1),
#  ('viverra.', 1),
#  ('lacinia,', 1),
#  ('tempus.', 1),
#  ('iaculis,', 1),
#  ('finibus,', 1),
#  ('vehicula,', 1),
#  ('dictum,', 1),
#  ('porttitor,', 1),
#  ('elementum.', 2),
#  ('ultricies,', 2),
#  ('Orci', 2),
#  ('natoque', 2),
#  ('dis', 2),
#  ('nascetur', 2),
#  ('mus.', 2),
#  ('molestie,', 2),
#  ('lobortis,', 2),
#  ('congue.', 2),
#  ('congue,', 2),
#  ('lacinia.', 2),
#  ('ex,', 2),
#  ('cubilia', 2),
#  ('curae;', 2),
#  ('facilisis.', 2),
#  ('condimentum,', 2),
# ...

# %%
phase_five.coalesce(1).saveAsTextFile("./output")

# %%
phase_five.take(10)
# Out:
# [('ultrices,', 1),
#  ('condimentum.', 1),
#  ('venenatis,', 1),
#  ('vitae.', 1),
#  ('tempus,', 1),
#  ('viverra.', 1),
#  ('lacinia,', 1),
#  ('viverra,', 1),
#  ('turpis,', 1),
#  ('gravida,', 1)]

# %%
phase_two.countByKey()
# Out:
# defaultdict(int,
#             {'Lorem': 7,
#              'ipsum': 33,
#              'dolor': 18,
#              'sit': 62,
#              'amet,': 12,
#              'consectetur': 21,
#              'adipiscing': 7,
#              'elit.': 15,
#              'Nunc': 17,
#              'vitae': 54,
#              'tempor': 14,
#              'tortor.': 14,
#              'Suspendisse': 25,
#              'nec': 47,
#              'ultrices': 17,
#              'ex.': 9,
#              'Etiam': 29,
#              'non': 48,
#              'egestas': 27,
#              'mi.': 5,
#              'Nulla': 22,
#              'massa,': 6,
#              'auctor': 23,
#              'et': 85,
#              'accumsan': 23,
#              'id,': 7,
#              'fringilla': 23,
#              'in': 49,
#              'hendrerit': 15,
#              'lectus': 21,
#              'enim': 17,
#              'fermentum': 17,
#              'consequat.': 5,
#              'Maecenas': 18,
# ...

# %%
accum_counter = session.sparkContext.accumulator(0)

# %%
def add_to(x):
    accum_counter.add(1)

phase_five.foreach(add_to)
accum_counter.value
# Out:
# 908

# %%
def add_to(x):
    accum_counter.add(1)
phase_five.map(add_to)
accum_counter.value
# Out:
# 1816

# %%
session.stop()
